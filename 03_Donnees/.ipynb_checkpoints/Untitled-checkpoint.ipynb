# %%
import pandas as pd
import numpy as np

from plotnine import *

# %matplotlib inline
# Out:
# /home/essicolo/bin/anaconda3/lib/python3.5/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
df = pd.DataFrame({
    'variable': ['gender', 'gender', 'age', 'age', 'age', 'income', 'income', 'income', 'income'],
    'category': ['Female', 'Male', '1-24', '25-54', '55+', 'Lo', 'Lo-Med', 'Med', 'High'],
    'value': [60, 40, 50, 30, 20, 10, 25, 25, 40],
})
df['variable'] = pd.Categorical(df['variable'], categories=['gender', 'age', 'income'])

df
# Out:
#   category  value variable
# 0   Female     60   gender
# 1     Male     40   gender
# 2     1-24     50      age
# 3    25-54     30      age
# 4      55+     20      age
# 5       Lo     10   income
# 6   Lo-Med     25   income
# 7      Med     25   income
# 8     High     40   income

# %%
chicoute = pd.read_csv('data/chicoute.csv', sep=';', header=0, index_col=0, na_values='',
                 encoding='utf-8')

# %%
chicoute.head()
# Out:
#    CodeTourbiere Ordre  Site Traitement DemiParcelle SousTraitement  \
# ID
# 1           BEAU     A     1        NaN          NaN            NaN
# 2           BEAU     A     2        NaN          NaN            NaN
# 3           BEAU     A     3        NaN          NaN            NaN
# 4           BEAU     A     4        NaN          NaN            NaN
# 5           BEAU     A     5        NaN          NaN            NaN
#
#     Latitude_m  Longitude_m  Rendement_g.5m2  TotalRamet_nombre.m2    ...     \
# ID                                                                    ...
# 1      5702454       490627              NaN            453.272218    ...
# 2      5702452       490634              NaN            460.911637    ...
# 3      5702461       490638              NaN            651.897122    ...
# 4      5702453       490647              NaN            590.781767    ...
# 5      5702445       490654              NaN            564.043799    ...
#
# ...

# %%
import matplotlib.pylab as plt

# %%
import ggplot as ggpy

ggpy.ggplot(chicoute, aes(x='N_pourc', y='K_pourc', colour='CodeTourbiere')) +\
    geom_point() +\
    theme_bw()
# Out:
# <ggplot: (-9223363264224694752)>

# %%
import plotnine as p9

p9.ggplot(chicoute, aes(x='N_pourc', y='K_pourc', colour='CodeTourbiere')) +\
    geom_point() +\
    theme_bw()
